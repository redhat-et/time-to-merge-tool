# %% [markdown]
# # Pull Requests Data Collection
#
# In this notebook, we will collect the raw Pull Request data from a github repo of choice, and save it as a json file on an s3 bucket. To do this, we will use the `srcopsmetrics` tool developed by the Thoth team.

# %%
import os

from dotenv import find_dotenv, load_dotenv

load_dotenv(find_dotenv(), override=True)
# Out:
# True

# %% [markdown]
# ## Set Environment variables
#
# Before you start, make sure to create a .env file at the root of the repository with the required credentials and paths. Refer to workshop section **"Set your Environment Variables"** for details on how to set it and this example [file](env_example_workshop) for the structure.

# %%
# get the org/repo from env vars
ORG = os.getenv("GITHUB_ORG")
REPO = os.getenv("GITHUB_REPO")
CEPH_BUCKET_PREFIX = os.getenv("CEPH_BUCKET_PREFIX")

print(f"{ORG}/{REPO}")
print(
    f"Downloaded file is being stored at {CEPH_BUCKET_PREFIX}/srcopsmetrics/bot_knowledge/{ORG}/{REPO}/PullRequest.json"
)
# Out:
# operate-first/operations
# Downloaded file is being stored at nov/srcopsmetrics/bot_knowledge/operate-first/operations/PullRequest.json

# %%
# run collection on the org/repo specified
# !python -m srcopsmetrics.cli --create-knowledge --repository $ORG/$REPO --entities PullRequest
# Out:
# INFO:srcopsmetrics.github_knowledge:Overall repositories found: 1
# INFO:srcopsmetrics.bot_knowledge:######################## Analysing operate-first/operations ########################
#
# INFO:srcopsmetrics.utils:No repo identified, creating new directory at /__w/ttmtool/ttmtool/srcopsmetrics/bot_knowledge/operate-first/operations
# INFO:srcopsmetrics.bot_knowledge:########################
# INFO:srcopsmetrics.bot_knowledge:Detected entities:
# CodeFrequency # Commit # DependencyUpdate # Fork # Issue # IssueEvent # KebechetUpdateManager # License # PullRequest # PullRequestDiscussion # RawIssue # RawPullRequest # ReadMe # Release # Stargazer # ThothAdviseMetrics # ThothMetrics # ThothMetrics # ThothMetrics # ThothVersionManagerMetrics # TrafficClones # TrafficPaths # TrafficPaths # TrafficReferrers # TrafficClones # TrafficViews
# INFO:srcopsmetrics.bot_knowledge:########################
# INFO:srcopsmetrics.bot_knowledge:PullRequest inspection
# INFO:srcopsmetrics.entities.tools.storage:Loading knowledge from Ceph
# INFO:srcopsmetrics.entities.tools.storage:Knowledge srcopsmetrics/bot_knowledge/operate-first/operations/PullRequest.json not found on Ceph
# INFO:srcopsmetrics.entities.interface:No previous knowledge of type PullRequest found
# INFO:srcopsmetrics.iterator:-------------PullRequest Analysis-------------
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #443
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #438
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/2
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/2
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #420
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #412
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #409
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #397
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 4/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 5/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 6/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 7/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 8/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 9/9
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #395
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #387
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/2
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/2
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #367
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #360
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/3
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/3
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/3
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #344
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/2
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/2
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #338
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #316
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #285
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/3
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/3
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/3
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #279
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #262
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #258
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/2
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/2
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #257
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #255
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #244
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #237
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #233
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/23
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/23
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/23
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 4/23
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 5/23
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 6/23
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 7/23
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 8/23
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 9/23
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 10/23
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 11/23
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 12/23
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 13/23
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 14/23
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 15/23
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 16/23
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 17/23
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 18/23
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 19/23
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 20/23
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 21/23
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 22/23
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 23/23
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #232
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/8
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/8
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/8
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 4/8
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 5/8
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 6/8
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 7/8
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 8/8
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #231
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/17
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/17
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/17
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 4/17
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 5/17
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 6/17
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 7/17
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 8/17
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 9/17
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 10/17
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 11/17
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 12/17
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 13/17
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 14/17
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 15/17
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 16/17
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 17/17
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #130
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/3
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/3
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/3
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #115
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/10
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/10
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/10
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 4/10
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 5/10
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 6/10
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 7/10
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 8/10
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 9/10
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 10/10
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #114
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #65
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #64
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #55
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/2
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/2
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #54
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/3
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/3
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/3
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #53
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/6
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/6
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/6
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 4/6
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 5/6
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 6/6
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #35
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 4/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 5/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 6/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 7/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 8/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 9/9
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #31
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/2
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/2
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #30
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #29
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/2
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/2
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #22
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/2
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/2
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #21
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/4
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/4
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/4
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 4/4
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #17
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 4/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 5/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 6/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 7/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 8/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 9/9
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #15
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/4
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/4
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/4
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 4/4
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #10
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/2
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/2
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #7
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #6
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/2
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/2
# 100%|███████████████████████| 44/44 [01:32<00:00,  2.10s/it, RATE remaining=608]
# INFO:srcopsmetrics.entities.interface:Knowledge file PullRequest.json
# INFO:srcopsmetrics.entities.interface:new 44 entities
# INFO:srcopsmetrics.entities.interface:(overall 44 entities)
# INFO:srcopsmetrics.entities.interface:Saved on CEPH at opf-datacatalog/nov/srcopsmetrics/bot_knowledge/operate-first/operations/PullRequest.json
# INFO:srcopsmetrics.bot_knowledge:

# %% [markdown]
# # Conclusion
#
# By running this notebook we have collected and stored the github PR data to our s3 bucket. It is now ready for the cleaning and feature engineering steps of the ML workflow.
#
# # Next Step
#
# In the next [notebook](./02_feature_engineering.ipynb), we will engineer some features from the raw PR data which can be used to train a ML model
