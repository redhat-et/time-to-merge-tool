# %% [markdown]
# # Pull Requests Data Collection
#
# In this notebook, we will collect the raw Pull Request data from a github repo of choice, and save it as a json file on an s3 bucket. To do this, we will use the `srcopsmetrics` tool developed by the Thoth team.

# %%
import os

from dotenv import find_dotenv, load_dotenv

load_dotenv(find_dotenv(), override=True)
# Out:
# True

# %% [markdown]
# ## Set Environment variables
#
# Before you start, make sure to create a .env file at the root of the repository with the required credentials and paths. Refer to workshop section **"Set your Environment Variables"** for details on how to set it and this example [file](env_example_workshop) for the structure.

# %%
# get the org/repo from env vars
ORG = os.getenv("GITHUB_ORG")
REPO = os.getenv("GITHUB_REPO")
CEPH_BUCKET_PREFIX = os.getenv("CEPH_BUCKET_PREFIX")

print(f"{ORG}/{REPO}")
print(
    f"Downloaded file is being stored at {CEPH_BUCKET_PREFIX}/srcopsmetrics/bot_knowledge/{ORG}/{REPO}/PullRequest.json"
)
# Out:
# operate-first/community
# Downloaded file is being stored at nov/srcopsmetrics/bot_knowledge/operate-first/community/PullRequest.json

# %%
# run collection on the org/repo specified
# !python -m srcopsmetrics.cli --create-knowledge --repository $ORG/$REPO --entities PullRequest
# Out:
# INFO:srcopsmetrics.github_knowledge:Overall repositories found: 1
# INFO:srcopsmetrics.bot_knowledge:######################## Analysing operate-first/community ########################
#
# INFO:srcopsmetrics.utils:No repo identified, creating new directory at /__w/ttmtool/ttmtool/srcopsmetrics/bot_knowledge/operate-first/community
# INFO:srcopsmetrics.bot_knowledge:########################
# INFO:srcopsmetrics.bot_knowledge:Detected entities:
# CodeFrequency # Commit # DependencyUpdate # Fork # Issue # IssueEvent # KebechetUpdateManager # License # PullRequest # PullRequestDiscussion # RawIssue # RawPullRequest # ReadMe # Release # Stargazer # ThothAdviseMetrics # ThothMetrics # ThothMetrics # ThothMetrics # ThothVersionManagerMetrics # TrafficClones # TrafficPaths # TrafficPaths # TrafficReferrers # TrafficClones # TrafficViews
# INFO:srcopsmetrics.bot_knowledge:########################
# INFO:srcopsmetrics.bot_knowledge:PullRequest inspection
# INFO:srcopsmetrics.entities.tools.storage:Loading knowledge from Ceph
# INFO:srcopsmetrics.entities.tools.storage:Knowledge srcopsmetrics/bot_knowledge/operate-first/community/PullRequest.json not found on Ceph
# INFO:srcopsmetrics.entities.interface:No previous knowledge of type PullRequest found
# INFO:srcopsmetrics.iterator:-------------PullRequest Analysis-------------
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #230
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #229
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #228
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #225
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #224
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #223
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #222
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #221
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #220
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 4/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 5/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 6/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 7/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 8/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 9/9
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #219
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #218
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #217
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #216
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #214
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #213
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #212
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #211
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #210
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/4
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/4
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/4
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 4/4
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #209
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #208
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #207
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/4
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/4
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/4
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 4/4
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #204
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 4/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 5/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 6/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 7/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 8/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 9/9
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #203
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/2
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/2
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #198
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #194
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #193
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/10
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/10
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/10
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 4/10
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 5/10
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 6/10
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 7/10
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 8/10
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 9/10
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 10/10
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #185
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #184
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/6
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/6
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/6
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 4/6
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 5/6
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 6/6
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #183
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #182
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #179
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #178
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #177
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #176
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #171
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #170
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #169
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #168
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #167
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #166
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 4/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 5/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 6/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 7/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 8/9
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 9/9
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #164
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #163
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #162
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #161
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #160
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #159
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #158
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #156
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #155
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #154
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/2
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/2
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #153
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #152
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/2
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/2
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #151
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #149
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/11
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/11
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/11
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 4/11
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 5/11
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 6/11
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 7/11
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 8/11
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 9/11
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 10/11
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 11/11
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #147
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #146
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #145
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #144
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #143
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #139
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/3
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/3
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/3
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #138
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/2
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/2
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #137
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #135
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/11
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/11
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/11
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 4/11
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 5/11
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 6/11
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 7/11
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 8/11
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 9/11
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 10/11
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 11/11
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #133
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/4
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/4
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/4
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 4/4
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #132
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #130
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/3
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/3
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/3
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #128
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #127
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/24
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/24
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/24
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 4/24
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 5/24
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 6/24
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 7/24
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 8/24
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 9/24
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 10/24
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 11/24
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 12/24
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 13/24
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 14/24
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 15/24
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 16/24
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 17/24
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 18/24
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 19/24
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 20/24
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 21/24
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 22/24
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 23/24
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 24/24
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #126
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #125
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #124
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/21
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/21
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/21
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 4/21
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 5/21
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 6/21
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 7/21
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 8/21
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 9/21
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 10/21
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 11/21
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 12/21
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 13/21
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 14/21
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 15/21
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 16/21
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 17/21
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 18/21
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 19/21
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 20/21
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 21/21
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #122
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/4
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/4
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/4
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 4/4
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #120
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/32
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/32
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/32
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 4/32
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 5/32
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 6/32
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 7/32
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 8/32
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 9/32
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 10/32
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 11/32
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 12/32
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 13/32
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 14/32
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 15/32
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 16/32
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 17/32
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 18/32
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 19/32
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 20/32
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 21/32
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 22/32
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 23/32
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 24/32
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 25/32
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 26/32
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 27/32
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 28/32
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 29/32
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 30/32
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 31/32
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 32/32
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #119
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #118
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #117
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #116
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #115
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #114
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #113
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #110
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #107
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 4/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 5/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 6/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 7/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 8/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 9/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 10/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 11/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 12/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 13/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 14/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 15/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 16/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 17/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 18/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 19/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 20/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 21/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 22/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 23/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 24/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 25/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 26/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 27/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 28/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 29/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 30/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 31/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 32/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 33/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 34/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 35/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 36/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 37/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 38/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 39/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 40/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 41/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 42/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 43/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 44/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 45/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 46/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 47/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 48/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 49/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 50/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 51/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 52/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 53/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 54/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 55/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 56/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 57/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 58/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 59/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 60/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 61/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 62/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 63/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 64/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 65/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 66/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 67/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 68/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 69/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 70/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 71/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 72/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 73/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 74/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 75/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 76/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 77/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 78/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 79/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 80/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 81/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 82/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 83/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 84/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 85/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 86/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 87/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 88/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 89/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 90/91
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 91/91
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #106
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #105
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #82
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #80
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/2
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/2
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #70
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/2
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/2
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #48
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #47
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/4
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/4
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/4
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 4/4
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #46
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #45
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #44
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #43
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/4
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/4
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/4
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 4/4
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #5
# ERROR:srcopsmetrics.entities.tools.knowledge:Size label not found
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/3
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 2/3
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 3/3
# INFO:srcopsmetrics.entities.pull_request:Extracting PR #1
# INFO:srcopsmetrics.entities.pull_request:      -analysing review no. 1/1
# 100%|███████████████████████| 95/95 [03:33<00:00,  2.25s/it, RATE remaining=148]
# INFO:srcopsmetrics.entities.interface:Knowledge file PullRequest.json
# INFO:srcopsmetrics.entities.interface:new 95 entities
# INFO:srcopsmetrics.entities.interface:(overall 95 entities)
# INFO:srcopsmetrics.entities.interface:Saved on CEPH at opf-datacatalog/nov/srcopsmetrics/bot_knowledge/operate-first/community/PullRequest.json
# INFO:srcopsmetrics.bot_knowledge:

# %% [markdown]
# # Conclusion
#
# By running this notebook we have collected and stored the github PR data to our s3 bucket. It is now ready for the cleaning and feature engineering steps of the ML workflow.
#
# # Next Step
#
# In the next [notebook](./02_feature_engineering.ipynb), we will engineer some features from the raw PR data which can be used to train a ML model
